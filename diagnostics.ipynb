# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Rhen email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# Starting diagnostics at 2025-05-17 14:29:26
#
# ===== System Information =====
# Operating System: Windows
# Windows Release: 10
# Windows Version: 10.0.26100
# Architecture: ('64bit', 'WindowsPE')
# Machine: AMD64
# Processor: Intel64 Family 6 Model 158 Stepping 13, GenuineIntel
# Total RAM: 31.83 GB
# Available RAM: 21.46 GB
# Free Disk Space: 102.63 GB
#
# ===== File System Information =====
# Current Directory: E:\Projects\llm_engineering
# Write permission: OK
#
# Files in Current Directory:
#  - .git
#  - .gitignore
#  - .ipynb_checkpoints
#  - LICENSE
#  - README.md
#  - SETUP-PC.md
#  - SETUP-PC.pdf
#  - SETUP-linux.md
#  - SETUP-linux.pdf
#  - SETUP-mac.md
#  - SETUP-mac.pdf
#  - __pycache__
#  - business.jpg
#  - community-contributions
#  - diagnostics.ipynb
#  - diagnostics.py
#  - environment.yml
#  - extras
#  - important.jpg
#  - report.txt
#  - requirements.txt
#  - resources.jpg
#  - thankyou.jpg
#  - voyage.jpg
#  - week1
#  - week2
#  - week3
#  - week4
#  - week5
#  - week6
#  - week7
#  - week8
#
# ===== Git Repository Information =====
# Git Repository Root: E:/Projects/llm_engineering
# Current Commit: 111028cf9bcdffbf70c5406680bac6c25ab23a74
# Remote Origin: https://github.com/ed-donner/llm_engineering.git
#
# ===== Environment File Check =====
# WARNING: .env file not found in project root
#
# ===== Anaconda Environment Check =====
# Anaconda environment is active:
# Environment Path: C:\Users\scott\miniconda3\envs\llms
# Environment Name: llms
# Conda Version: conda 24.11.3
#
# Python Environment:
# Python Version: 3.11.12 | packaged by conda-forge | (main, Apr 10 2025, 22:09:00) [MSC v.1943 64 bit (AMD64)]
# Python Executable: C:\Users\scott\miniconda3\envs\llms\python.exe
#
# Required Package Versions:
# openai: 1.79.0
# python-dotenv: 1.1.0
# requests: 2.32.3
# gradio: 5.29.1
# transformers: 4.51.3
#
# ===== Virtualenv Check =====
# No active virtualenv detected
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.5.0 8 Apr 2025
# ✓ Connected to https://www.google.com
#   Response time: 0.14s
#
# Performing bandwidth test using speedtest-cli...
